# %%
import os
import numpy as np

import matplotlib.pyplot as plt
import tensorflow as tf
from  keras.layers import *
from keras.models import *
from keras.preprocessing import image
from keras.applications import mobilenet_v2

# %%
loaded_model = tf.keras.models.load_model('MobiNet.h5')
print("Loaded model from Disk")
# Out:
# Loaded model from Disk

# %%
loaded_model.compile(loss=tf.keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

# %%
Test_path = 'Test'

Category = ['COVID','NORMAL']

input_path = 'Coviddataset/Train'

Target_path = 'Coviddataset/Val'

for i in os.listdir(Test_path):
    if i == 'Thumbs.db':
        break
    img = image.load_img(Test_path+'//'+i,target_size=(224,224),interpolation='nearest')

    img=tf.keras.preprocessing.image.img_to_array(img)

    print(i)
    
    plt.imshow(img/255.)
    
    plt.show()

    img = mobilenet_v2.preprocess_input(img)
    
    predictions=loaded_model.predict(np.array([img]))
    print('COVID:')
    Cov =predictions[0][0]

    print(Cov*100 ,'%')

    print('NORMAL:')

    Nor = predictions[0][1]

    print(Nor*100 , '%')
# Out:
# 01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg
# COVID:
# 100.0 %
# NORMAL:
# 6.11838621691267e-13 %
# 1-s2.0-S0140673620303706-fx1_lrg.jpg
# COVID:
# 3.214163794796479e-15 %
# NORMAL:
# 100.0 %
# 1-s2.0-S1684118220300608-main.pdf-001.jpg
# COVID:
# 99.99910593032837 %
# NORMAL:
# 0.0008891656761988997 %
# 1-s2.0-S1684118220300608-main.pdf-002.jpg
# COVID:
# 78.81602048873901 %
# NORMAL:
# 21.183981001377106 %
# NORMAL2-IM-0327-0001.jpeg
# COVID:
# 8.481439542145356e-17 %
# NORMAL:
# 100.0 %
# NORMAL2-IM-1427-0001.jpeg
# COVID:
# 7.2002480366872845e-09 %
# NORMAL:
# 100.0 %
# NORMAL2-IM-1430-0001.jpeg
# COVID:
# 5.925248486304824e-09 %
# NORMAL:
# 100.0 %
# NORMAL2-IM-1431-0001.jpeg
# COVID:
# 1.1164610347336179e-07 %
# NORMAL:
# 100.0 %
# NORMAL2-IM-1436-0001.jpeg
# COVID:
# 1.2931500217427255e-11 %
# NORMAL:
# 100.0 %
